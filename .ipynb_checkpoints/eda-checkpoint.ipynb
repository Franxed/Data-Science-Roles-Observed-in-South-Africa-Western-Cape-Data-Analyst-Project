# %% [markdown]
# # Part 2:
# ## Exploratory Data Analyses:
# ### This notebook analyses 190 data job listings scraped from Indeed and LinkedIn in the Western Cape, South Africa in June 2026. The goal is to understand which roles are most in demand, which companies are actively hiring, what seniority levels dominate the market and which technical skills appear most frequently in job descriptions. Data was collected using a custom Python scraper and cleaned in Part 1

# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Import the cleaned csv file created in part 1

# %%
df = pd.read_csv('wc_jobs_cleaned.csv')
df
# Out:
#         Search Word   Website  \
# 0      Data Analyst    indeed
# 1      Data Analyst    indeed
# 2      Data Analyst    indeed
# 3      Data Analyst    indeed
# 4      Data Analyst    indeed
# ..              ...       ...
# 185  Data Architect  linkedin
# 186  Data Architect  linkedin
# 187  Data Architect  linkedin
# 188  Data Architect  linkedin
# 189  Data Architect  linkedin
#
#                                                 Title  \
# 0                                 Claims Risk Analyst
# 1    Senior Application Support Analyst (SQL-focused)
# 2                       Business Intelligence Analyst
# 3                           Technical Product Analyst
# 4                                   Utilities Analyst
# ..                                                ...
# 185                          Data Strategy Consultant
# 186                              Senior Data Engineer
# 187                               Lead Data Scientist
# 188                               Senior Data Analyst
# 189             Product Manager - Group Data Platform
#
#                      Company  Remote Date Posted           Location  \
# 0            Momentum Health   False  2026-06-12          Bellville
# 1               MRI Software   False  2026-06-12          Cape Town
# 2                 LekkeSlaap    True  2026-06-12          Cape Town
# 3                     Sanlam   False  2026-06-12          Bellville
# 4    FPG Property Management   False  2026-06-12          Cape Town
# ..                       ...     ...         ...                ...
# 185                     Tiko   False  2026-06-08  City of Cape Town
# 186            DigiOutsource   False  2026-06-06          Cape Town
# 187      Network Recruitment   False  2026-06-02  City of Cape Town
# 188               impact.com   False     Unknown          Cape Town
# 189                   Sanlam   False     Unknown          Cape Town
#
#           City      Level   Job Type  \
# 0    Cape Town  Mid-Level    Unknown
# 1    Cape Town     Senior  Full-Time
# 2    Cape Town  Mid-Level  Full-Time
# 3    Cape Town  Mid-Level    Unknown
# 4    Cape Town  Mid-Level  Full-Time
# ..         ...        ...        ...
# 185  Cape Town  Mid-Level    Unknown
# 186  Cape Town     Senior    Unknown
# 187  Cape Town  Mid-Level    Unknown
# 188  Cape Town     Senior    Unknown
# 189  Cape Town  Mid-Level    Unknown
#
#                                            Description
# 0    Introduction Through our client-facing brands ...
# 1    MRI Software is seeking a Senior Application S...
# 2    Bring 3+ years of proven experience in busines...
# 3    Who are we? Sanlam Life and Savings (SLS) is f...
# 4    PURPOSE OF JOB The Utilities Analyst is respon...
# ..                                                 ...
# 185                                            Unknown
# 186                                            Unknown
# 187                                            Unknown
# 188                                            Unknown
# 189                                            Unknown
#
# [190 rows x 11 columns]

# %% [markdown]
# ## By looking at my cleaned dataset, I want to see how I can 'play' or work with the data. Identifying relationships and creating graphs that reflects these.

# %% [markdown]
# ### Who are the Top 10 most hiring companies in Western Cape are:

# %%
df['Company'].value_counts()[:10]
# Out:
# Company
# ExecutivePlacements.com    16
# Agoda                       9
# Capitec                     8
# Sanlam                      6
# impact.com                  5
# Mindrift                    4
# MRI Software                3
# Weaver Fintech Ltd          3
# Network Recruitment         3
# Communicate Recruitment     3
# Name: count, dtype: int64

# %% [markdown]
# # What seniority level does the market need?

# %% [markdown]
# ### Let's look which Seniority level are most sought after:

# %%
df['Level'].value_counts()
# Out:
# Level
# Mid-Level    135
# Senior        48
# Junior         7
# Name: count, dtype: int64

# %%
sen_count = df['Level'].value_counts()
seniority = df['Level'].value_counts().index
plt.pie(sen_count, labels=seniority)
plt.title("Most sought after Seniority level")
plt.show()

# %%
sen_lev_plot = sns.countplot(data=df, x='Level', hue='Level', order=df['Level'].value_counts().index)
for container in sen_lev_plot.containers:
    sen_lev_plot.bar_label(container)
plt.title("Most sought after Seniority level")
plt.xlabel("Seniority Level")
plt.ylabel("Number of Listings")
plt.show()

# %% [markdown]
# ### 135 mid-level, 48 senior and 7 junior. That's a tough market for someone just starting out. Only 3.68% of listings are entry level. The Western Cape data market expects prior experience and junior roles are scarce. Candidates without experience should consider internships, freelance projects, or building a portfolio to bridge the gap.

# %% [markdown]
# ## Furthermore, I noticed many labels for basically the same job:

# %%
df['Title'].value_counts()[:60]
# Out:
# Title
# Data Analyst                                                              5
# Senior Data Engineer                                                      5
# Business Intelligence Analyst                                             4
# FinOps Analyst                                                            2
# Yield Analyst                                                             2
# Business Process Analyst                                                  2
# Senior Data Analyst                                                       2
# Data Engineer                                                             2
# Quantitative Analyst                                                      2
# Data Scientist                                                            2
# Machine Learning Engineer                                                 2
# Lead Machine Learning Engineer                                            2
# Lead Data Scientist                                                       2
# Analyst                                                                   2
# Technical Business Analyst                                                2
# Business Analyst                                                          2
# Senior Analytics Engineer                                                 2
# Claims Risk Analyst                                                       1
# Senior Application Support Analyst (SQL-focused)                          1
# Technical Product Analyst                                                 1
# Utilities Analyst                                                         1
# Data Integrations Specialist - Client Focus                               1
# Senior BI Analyst - Team Leader                                           1
# Domain / Product owner - HR systems                                       1
# Customer Success Reporting Analyst                                        1
# Conflict Analyst                                                          1
# Paid Media Analyst                                                        1
# Supply Chain Process Analyst                                              1
# BUSINESS ANALYST (INDUSTRIAL ENGINEER)                                    1
# Manager, Grade 1: Spatial Analyst                                         1
# Integration Engineer/Developer                                            1
# Insight Analyst (Professional, BI Specialist (TCF))                       1
# Investment Guidelines Analyst (Contractor)                                1
# Databricks Data Engineer                                                  1
# Commercial Finance Business Analyst                                       1
# Quality Analyst                                                           1
# Supply Chain Analyst                                                      1
# Data Management Analyst                                                   1
# Junior Credit Risk Analyst                                                1
# Sales Analyst (6 Month Contract)                                          1
# CRM & Data Analyst                                                        1
# Realtime Analyst                                                          1
# Quality Analyst - Financial Services - Onsite - Cape Town                 1
# Senior Retail Media Insights Analyst                                      1
# Digital Data Analyst (Rainmaker Media)                                    1
# Business Intelligence Analyst (Retail) - Corporate Placements             1
# Data Engineer (Senior)                                                    1
# Applied Research Engineer                                                 1
# BI Analyst                                                                1
# Senior Space Analyst                                                      1
# Market Research Data Analyst                                              1
# Data Analyst (Marketing Analytics, Bangkok Based, Relocation provided)    1
# Data Engineer - Databricks - July Start                                   1
# Fundraising Systems and Data Specialist (m/f/d)                           1
# Junior Data Engineer                                                      1
# Business Data Analyst                                                     1
# Data & Insights Analyst                                                   1
# Client Reporting Analyst (12-month contract) – Investment Management      1
# Remote Data/Image Collector (No Experience Needed)                        1
# Data Analyst II_Pipeline                                                  1
# Name: count, dtype: int64

# %% [markdown]
# ### To tackle this, I am using Numpy to group all the Data Analysts, Data Scientists, Data Engineers & Architects together in their respective fields. Then adding them as a new Column called 'Category':

# %%
conditions = [
    df['Title'].str.contains('analyst', case=False, na=False),
    df['Title'].str.contains('scientist', case=False, na=False),
    df['Title'].str.contains('engineer', case=False, na=False),
    df['Title'].str.contains('architect', case=False, na=False)]

choices = [
    'Analyst',
    'Data Scientist',
    'Engineer',
    'Data Architect']
# Important to note: Order matters. If a title matches two conditions, it gets the label of whichever condition comes first!!! 
df['Category'] = np.select(conditions, choices, default='Other')

# %% [markdown]
# ### Making sure the grouping worked and was added to the DataFrame:

# %%
df[:60]
# Out:
#      Search Word   Website                                              Title  \
# 0   Data Analyst    indeed                                Claims Risk Analyst
# 1   Data Analyst    indeed   Senior Application Support Analyst (SQL-focused)
# 2   Data Analyst    indeed                      Business Intelligence Analyst
# 3   Data Analyst    indeed                          Technical Product Analyst
# 4   Data Analyst    indeed                                  Utilities Analyst
# 5   Data Analyst    indeed        Data Integrations Specialist - Client Focus
# 6   Data Analyst    indeed                    Senior BI Analyst - Team Leader
# 7   Data Analyst    indeed                Domain / Product owner - HR systems
# 8   Data Analyst    indeed                                       Data Analyst
# 9   Data Analyst    indeed                 Customer Success Reporting Analyst
# 10  Data Analyst    indeed                      Business Intelligence Analyst
# 11  Data Analyst    indeed                                   Conflict Analyst
# 12  Data Analyst    indeed                                 Paid Media Analyst
# 13  Data Analyst    indeed                       Supply Chain Process Analyst
# 14  Data Analyst    indeed             BUSINESS ANALYST (INDUSTRIAL ENGINEER)
# 15  Data Analyst    indeed                  Manager, Grade 1: Spatial Analyst
# 16  Data Analyst    indeed                     Integration Engineer/Developer
# 17  Data Analyst    indeed  Insight Analyst (Professional, BI Specialist (...
# 18  Data Analyst    indeed         Investment Guidelines Analyst (Contractor)
# 19  Data Analyst    indeed                                     FinOps Analyst
# 20  Data Analyst    indeed                           Databricks Data Engineer
# 21  Data Analyst    indeed                                     FinOps Analyst
# 22  Data Analyst    indeed                Commercial Finance Business Analyst
# 23  Data Analyst    indeed                                    Quality Analyst
# 24  Data Analyst    indeed                               Supply Chain Analyst
# 25  Data Analyst    indeed                            Data Management Analyst
# 26  Data Analyst    indeed                         Junior Credit Risk Analyst
# 27  Data Analyst    indeed                   Sales Analyst (6 Month Contract)
# 28  Data Analyst    indeed                                 CRM & Data Analyst
# 29  Data Analyst    indeed                                   Realtime Analyst
# 30  Data Analyst    indeed                                      Yield Analyst
# 31  Data Analyst    indeed  Quality Analyst - Financial Services - Onsite ...
# 32  Data Analyst    indeed               Senior Retail Media Insights Analyst
# 33  Data Analyst    indeed             Digital Data Analyst (Rainmaker Media)
# 34  Data Analyst    indeed                           Business Process Analyst
# 35  Data Analyst  linkedin                                       Data Analyst
# 36  Data Analyst  linkedin  Business Intelligence Analyst (Retail) - Corpo...
# 37  Data Analyst  linkedin                             Data Engineer (Senior)
# 38  Data Analyst  linkedin                          Applied Research Engineer
# 39  Data Analyst  linkedin                                Senior Data Analyst
# 40  Data Analyst  linkedin                                         BI Analyst
# 41  Data Analyst  linkedin                                       Data Analyst
# 42  Data Analyst  linkedin                      Business Intelligence Analyst
# 43  Data Analyst  linkedin                      Business Intelligence Analyst
# 44  Data Analyst  linkedin                               Senior Space Analyst
# 56                                            Unknown   Analyst
# 57                                            Unknown  Engineer
# 58                                            Unknown   Analyst
# 59                                            Unknown     Other

# %% [markdown]
# #### Great! Now to count them all together:

# %%
df['Category'].value_counts()
# Out:
# Category
# Analyst           92
# Engineer          64
# Other             14
# Data Scientist    12
# Data Architect     8
# Name: count, dtype: int64

# %% [markdown]
# ### Analysts dominate the market. They make up the largest category by far. This says  the WC market needs people who can interpret and communicate data more than people who build infrastructure. Good news for someone targeting a junior analyst role.

# %% [markdown]
# ## Displaying the distribution of Job Roles to visually represent what the data is saying:

# %%
category_plot = sns.countplot(data=df, x='Category', hue='Category', order=df['Category'].value_counts().index)
for container in category_plot.containers:
    category_plot.bar_label(container)
plt.title("Distribution of Job Roles in Western Cape")
plt.xlabel("Role Category")
plt.ylabel("Number of Listings")
plt.tight_layout() # Spacing between xlabels.
plt.show()

# %% [markdown]
# ### This is proof that Analysts and Engineers are the MOST sought after in June 2026, Western Cape, South Africa.

# %% [markdown]
# ## Now, let's look at the Top 10 most hiring Companies:

# %%
df.Company.value_counts()
# Out:
# Company
# ExecutivePlacements.com    16
# Agoda                       9
# Capitec                     8
# Sanlam                      6
# impact.com                  5
#                            ..
# Shoprite Holdings Ltd       1
# OLX                         1
# Meltwater                   1
# TM Forum                    1
# Tiko                        1
# Name: count, Length: 125, dtype: int64

# %% [markdown]
# ### ExecutivePlacements.com has 16 listings, but they're a recruitment agency, not a direct employer. The insight here is that a large portion of listings are posted by recruiters on behalf of unnamed companies, which means the actual employer market is more concentrated than it appears. Capitec and Sanlam are the standout direct employers.

# %% [markdown]
# ### As visually shown down below:

# %%
top_10_comp = df['Company'].value_counts().head(10)
plt.figure(figsize=(19, 6))
barplot = sns.barplot(x=top_10_comp.values, y=top_10_comp.index) # Top 10 companies.
for container in barplot.containers:
    barplot.bar_label(container)
plt.title('Top 10 Most Hiring Companies in the Western Cape')
plt.xlabel("Top 10 Companies")
plt.ylabel("Number of Listings")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## How many Jobs provide Remote job types:

# %%
df['Remote'].value_counts()
# Out:
# Remote
# False    179
# True      11
# Name: count, dtype: int64

# %% [markdown]
# ### Only 11 remote listings out of 190 which is less than 6% (5.79%). The WC data job market is overwhelmingly for the on-site job type. That's a meaningful finding for anyone job hunting remotely.

# %% [markdown]
# ## Let's look how are locations distributed:

# %% [markdown]
# ### Chart 1 - How many listings per city:

# %%
plt.figure(figsize=(8, 5))
loc_plot = sns.countplot(data=df, x='City', order=df['City'].value_counts().index)
for container in loc_plot.containers:
    loc_plot.bar_label(container)
plt.title('Job Listings by City in the Western Cape')
plt.xlabel('City')
plt.ylabel('Number of Listings')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Chart 2 - Remote vs On-site per city:

# %%
plt.figure(figsize=(8, 5))
loc_remote = sns.countplot(data=df, x='City', hue='Remote', order=df['City'].value_counts().index)
for container in loc_remote.containers:
    loc_remote.bar_label(container)
plt.title('On-site vs Remote Listings by City')
plt.xlabel('City')
plt.ylabel('Number of Listings')
plt.legend(labels=['On-site', 'Remote'])
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Cape Town accounts for 91% of all listings, confirming it is the dominant hub for data roles in the Western Cape. Stellenbosch is a distant second driven largely by Capitec's presence. Remote opportunities are minimal across all cities, meaning physical location is a real barrier to entry for most candidates.

# %% [markdown]
# # What skills are needed the most.
